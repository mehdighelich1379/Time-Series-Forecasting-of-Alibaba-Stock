# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , LSTM , GRU  , SimpleRNN
from tensorflow.keras.callbacks import EarlyStopping , ModelCheckpoint , ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_absolute_error , mean_squared_error
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Ali_Baba_Stock_Data.csv" )
data.head()
# Out:
#          Date  Adj Close      Close       High        Low       Open  \
# 0  2014-09-19  90.673950  93.889999  99.699997  89.949997  92.699997
# 1  2014-09-22  86.810966  89.889999  92.949997  89.500000  92.699997
# 2  2014-09-23  84.184128  87.169998  90.480003  86.620003  88.940002
# 3  2014-09-24  87.467667  90.570000  90.570000  87.220001  88.470001
# 4  2014-09-25  85.874191  88.919998  91.500000  88.500000  91.089996
#
#       Volume
# 0  271879400
# 1   66657800
# 2   39009800
# 3   32088000
# 4   28598000

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2617 entries, 0 to 2616
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2617 non-null   datetime64[ns]
#  1   Adj Close  2617 non-null   float64
#  2   Close      2617 non-null   float64
#  3   High       2617 non-null   float64
#  4   Low        2617 non-null   float64
#  5   Open       2617 non-null   float64
#  6   Volume     2617 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 143.2 KB

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.head()
# Out:
#         Date  Adj Close      Close       High        Low       Open     Volume
# 0 2014-09-19  90.673950  93.889999  99.699997  89.949997  92.699997  271879400
# 1 2014-09-22  86.810966  89.889999  92.949997  89.500000  92.699997   66657800
# 2 2014-09-23  84.184128  87.169998  90.480003  86.620003  88.940002   39009800
# 3 2014-09-24  87.467667  90.570000  90.570000  87.220001  88.470001   32088000
# 4 2014-09-25  85.874191  88.919998  91.500000  88.500000  91.089996   28598000

# %%
data.isnull().sum()
# Out:
# Date         0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                                 Date    Adj Close        Close         High  \
# count                           2617  2617.000000  2617.000000  2617.000000
# mean   2019-11-30 14:35:26.709973248   130.763001   135.153905   136.919684
# min              2014-09-19 00:00:00    55.424198    57.389999    58.650002
# 25%              2017-04-26 00:00:00    82.445793    84.849998    85.699997
# 50%              2019-11-29 00:00:00   105.469185   108.989998   110.650002
# 75%              2022-07-07 00:00:00   173.061798   179.199997   181.389999
# max              2025-02-13 00:00:00   306.276886   317.140015   319.320007
# std                              NaN    56.741744    58.951556    59.579593
#
#                Low         Open        Volume
# count  2617.000000  2617.000000  2.617000e+03
# mean    133.360942   135.248746  1.899231e+07
# min      57.200001    57.299999  3.775300e+06
# 25%      84.000000    85.000000  1.186070e+07
# 50%     107.260002   108.500000  1.600840e+07
# 75%     177.000000   179.369995  2.172430e+07
# max     308.910004   313.500000  2.718794e+08
# std      58.244218    59.037467  1.291504e+07

# %%
plt.plot(data['Date'], data["Close"] , label = 'Close Price' , c="green")
plt.legend()
plt.show()

# %%
X = data[["High","Low","Open","Volume"]].values
Y = data['Close'].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# %%
x_scale = scaler_x.fit_transform(X)
y_scale = scaler_y.fit_transform(Y.reshape(-1, 1))

# %%
x_train , x_test , y_train , y_test = train_test_split(x_scale , y_scale , test_size = 0.2 , shuffle=False)
print(f"len x_train : {len(x_train)} , len y_train : {len(y_train)}")
print(f"len x_test: {len(x_test)} , len y_test : {len(y_test)}")
# Out:
# len x_train : 2093 , len y_train : 2093
# len x_test: 524 , len y_test : 524

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
def create_dataset(X , Y, time_step=30):
    dataX = []
    dataY = []
    for i in range(len(X)-time_step):
        d = i + time_step
        dataX.append(X[i:d])
        dataY.append(Y[d])
    return np.array(dataX), np.array(dataY)

# %%
time_steps = 30
x_train , y_train = create_dataset(x_train, y_train, time_steps)
x_test , y_test = create_dataset(x_test, y_test, time_steps)

# %%
print(f"type of XT  is {type(x_train)}")
print(f"type of YT  is {type(y_train)}")
print(f"type of XT  is {type(x_test)}")
print(f"type of YT  is {type(y_test)}")
# Out:
# type of XT  is <class 'numpy.ndarray'>
# type of YT  is <class 'numpy.ndarray'>
# type of XT  is <class 'numpy.ndarray'>
# type of YT  is <class 'numpy.ndarray'>

# %%
x_train.shape
# Out:
# (2063, 30, 4)

# %%
y_train.shape
# Out:
# (2063, 1)

# %%
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2])

# %%
print(f"shape of XT is {x_train.shape}")
print(f"shape of YT is {y_train.shape}")
print(f"shape of xt is {x_test.shape}")
print(f"shape of yt is {y_test.shape}")
# Out:
# shape of XT is (2063, 30, 4)
# shape of YT is (2063, 1)
# shape of xt is (494, 30, 4)
# shape of yt is (494, 1)

# %% [markdown]
# RNN

# %%
model_rnn = Sequential()
model_rnn.add(SimpleRNN(50,activation="relu" , return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])))
model_rnn.add(SimpleRNN(50,activation="relu"))
model_rnn.add(Dense(1))

# %%
early_stopping2 = EarlyStopping(monitor="val_loss" , mode="min" , patience=30)
rrop2 = ReduceLROnPlateau(monitor="val_loss" , mode="min" , factor=0.5 , learning_rate=1e-6 , patience=20)
check_point2 = ModelCheckpoint("alibaba_model_RNN_Close.h5", monitor="val_loss" , save_best_only=True)

# %%
model_rnn.compile(optimizer="adam", loss='mean_absolute_error')
model_rnn.fit(x_train, y_train,validation_data=(x_test,y_test) ,  epochs=100, batch_size=32 , callbacks=[early_stopping2 , rrop2 , check_point2])
# Out:
# Epoch 1/100
# 65/65 [==============================] - 2s 9ms/step - loss: 0.0314 - val_loss: 0.0087 - lr: 0.0010
# Epoch 2/100
# 33/65 [==============>...............] - ETA: 0s - loss: 0.0147
# c:\Users\T A T\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0150 - val_loss: 0.0084 - lr: 0.0010
# Epoch 3/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 0.0074 - lr: 0.0010
# Epoch 4/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0144 - val_loss: 0.0074 - lr: 0.0010
# Epoch 5/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0127 - val_loss: 0.0069 - lr: 0.0010
# Epoch 6/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0128 - val_loss: 0.0066 - lr: 0.0010
# Epoch 7/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0126 - val_loss: 0.0071 - lr: 0.0010
# Epoch 8/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0123 - val_loss: 0.0075 - lr: 0.0010
# Epoch 9/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0125 - val_loss: 0.0065 - lr: 0.0010
# Epoch 10/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0128 - val_loss: 0.0067 - lr: 0.0010
# Epoch 11/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0065 - lr: 0.0010
# Epoch 12/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0067 - lr: 0.0010
# Epoch 13/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0066 - lr: 0.0010
# Epoch 14/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0064 - lr: 0.0010
# Epoch 15/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0116 - val_loss: 0.0063 - lr: 0.0010
# Epoch 16/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0070 - lr: 0.0010
# Epoch 17/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 0.0064 - lr: 0.0010
# Epoch 18/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0062 - lr: 0.0010
# Epoch 19/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0122 - val_loss: 0.0073 - lr: 0.0010
# Epoch 20/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0062 - lr: 0.0010
# Epoch 21/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0116 - val_loss: 0.0063 - lr: 0.0010
# Epoch 22/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 0.0062 - lr: 0.0010
# Epoch 23/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0065 - lr: 0.0010
# Epoch 24/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0113 - val_loss: 0.0066 - lr: 0.0010
# Epoch 25/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0117 - val_loss: 0.0063 - lr: 0.0010
# Epoch 26/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0118 - val_loss: 0.0064 - lr: 0.0010
# Epoch 27/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0114 - val_loss: 0.0072 - lr: 0.0010
# Epoch 28/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0070 - lr: 0.0010
# Epoch 29/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0063 - lr: 0.0010
# Epoch 30/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.0062 - lr: 0.0010
# Epoch 31/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0113 - val_loss: 0.0062 - lr: 0.0010
# Epoch 32/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0118 - val_loss: 0.0063 - lr: 0.0010
# Epoch 33/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0065 - lr: 0.0010
# Epoch 34/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0112 - val_loss: 0.0061 - lr: 0.0010
# Epoch 35/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0113 - val_loss: 0.0062 - lr: 0.0010
# Epoch 36/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0116 - val_loss: 0.0065 - lr: 0.0010
# Epoch 37/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0065 - lr: 0.0010
# Epoch 38/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0068 - lr: 0.0010
# Epoch 39/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0115 - val_loss: 0.0073 - lr: 0.0010
# Epoch 40/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0122 - val_loss: 0.0077 - lr: 0.0010
# Epoch 41/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0064 - lr: 5.0000e-04
# Epoch 42/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0108 - val_loss: 0.0062 - lr: 5.0000e-04
# Epoch 43/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0064 - lr: 5.0000e-04
# Epoch 44/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0062 - lr: 5.0000e-04
# Epoch 45/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0065 - lr: 5.0000e-04
# Epoch 46/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0106 - val_loss: 0.0061 - lr: 5.0000e-04
# Epoch 47/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0107 - val_loss: 0.0063 - lr: 5.0000e-04
# Epoch 48/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0109 - val_loss: 0.0062 - lr: 5.0000e-04
# Epoch 49/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0108 - val_loss: 0.0066 - lr: 5.0000e-04
# Epoch 50/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0109 - val_loss: 0.0062 - lr: 5.0000e-04
# Epoch 51/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0064 - lr: 5.0000e-04
# Epoch 52/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0063 - lr: 5.0000e-04
# Epoch 53/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.0064 - lr: 5.0000e-04
# Epoch 54/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0061 - lr: 5.0000e-04
# Epoch 55/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0061 - lr: 5.0000e-04
# Epoch 56/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0106 - val_loss: 0.0068 - lr: 5.0000e-04
# Epoch 57/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0111 - val_loss: 0.0064 - lr: 5.0000e-04
# Epoch 58/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0110 - val_loss: 0.0061 - lr: 5.0000e-04
# Epoch 59/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0104 - val_loss: 0.0062 - lr: 5.0000e-04
# Epoch 60/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0063 - lr: 5.0000e-04
# Epoch 61/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 62/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0062 - lr: 2.5000e-04
# Epoch 63/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0104 - val_loss: 0.0065 - lr: 2.5000e-04
# Epoch 64/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0105 - val_loss: 0.0068 - lr: 2.5000e-04
# Epoch 65/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0106 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 66/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 67/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0103 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 68/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0103 - val_loss: 0.0062 - lr: 2.5000e-04
# Epoch 69/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 70/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 71/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0105 - val_loss: 0.0062 - lr: 2.5000e-04
# Epoch 72/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 73/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 74/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0102 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 75/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0102 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 76/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0104 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 77/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0106 - val_loss: 0.0065 - lr: 2.5000e-04
# Epoch 78/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0062 - lr: 2.5000e-04
# Epoch 79/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0102 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 80/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 81/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0103 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 82/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 83/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 84/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 85/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 86/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0061 - lr: 1.2500e-04
# Epoch 87/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0061 - lr: 1.2500e-04
# Epoch 88/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 89/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 90/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 91/100
# 65/65 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0064 - lr: 1.2500e-04
# Epoch 92/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 93/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 94/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 95/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 96/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0061 - lr: 1.2500e-04
# Epoch 97/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0062 - lr: 1.2500e-04

# %%
model_rnn = load_model("alibaba_model_RNN_Close.h5")
model_rnn.evaluate(x_test,y_test)
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0061
# 0.006069089286029339

# %%
y_pred_rnn = model_rnn.predict(x_test)
date_for_pred = data['Date'][-len(y_pred_rnn):]
pred_rescale_rnn = scaler_y.inverse_transform(y_pred_rnn)
y_test_rescale = scaler_y.inverse_transform(y_test)

plt.figure(figsize=(15, 6) , facecolor="black")
plt.title("prediction vs true test data" , color="white" , fontsize=20)
plt.plot(date_for_pred , y_test_rescale,color = "red" , label='true test data')
plt.plot(date_for_pred , pred_rescale_rnn,color="blue" , label='prediction')

ax = plt.gca()
ax.set_facecolor("black")

plt.xlabel("Date" , color="white" , fontsize=15)
plt.xlabel("Date" , color="white" , fontsize=15)
plt.ylabel("stock price" , color="white" , fontsize=15)
plt.grid(True , color="gray")
plt.tick_params(colors="white")
plt.legend()
# Out:
# 16/16 [==============================] - 0s 3ms/step

# %% [markdown]
# GRU , LSTM

# %%
model_lstm_gru = Sequential()
model_lstm_gru.add(GRU(units = 50, return_sequences = True, activation = 'relu' , input_shape=(x_train.shape[1],x_train.shape[2])))
model_lstm_gru.add(LSTM(units = 50, activation = 'relu'))
model_lstm_gru.add(Dense(1))

# %%
early_stopping = EarlyStopping(monitor="val_loss" , mode="min" , patience=17)
rrop = ReduceLROnPlateau(monitor="val_loss" , mode="min" , factor=0.5 , learning_rate=1e-6 , patience=8)
check_point = ModelCheckpoint("alibaba_model_LSTM_GRU_Close.h5", monitor="val_loss" , save_best_only=True)

# %%
model_lstm_gru.compile(loss='mean_absolute_error', optimizer='adam')
history = model_lstm_gru.fit(x_train , y_train , validation_data=(x_test , y_test) , epochs = 100 , batch_size=10 , callbacks=[early_stopping , rrop , check_point])
# Out:
# Epoch 1/100
# 207/207 [==============================] - 4s 11ms/step - loss: 0.0509 - val_loss: 0.0118 - lr: 0.0010
# Epoch 2/100
#  13/207 [>.............................] - ETA: 1s - loss: 0.0251
# c:\Users\T A T\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0198 - val_loss: 0.0139 - lr: 0.0010
# Epoch 3/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0175 - val_loss: 0.0132 - lr: 0.0010
# Epoch 4/100
# 207/207 [==============================] - 2s 11ms/step - loss: 0.0180 - val_loss: 0.0107 - lr: 0.0010
# Epoch 5/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0163 - val_loss: 0.0117 - lr: 0.0010
# Epoch 6/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0154 - val_loss: 0.0087 - lr: 0.0010
# Epoch 7/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0155 - val_loss: 0.0091 - lr: 0.0010
# Epoch 8/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0146 - val_loss: 0.0080 - lr: 0.0010
# Epoch 9/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0145 - val_loss: 0.0077 - lr: 0.0010
# Epoch 10/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0145 - val_loss: 0.0079 - lr: 0.0010
# Epoch 11/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0135 - val_loss: 0.0084 - lr: 0.0010
# Epoch 12/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0128 - val_loss: 0.0080 - lr: 0.0010
# Epoch 13/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0130 - val_loss: 0.0072 - lr: 0.0010
# Epoch 14/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0132 - val_loss: 0.0068 - lr: 0.0010
# Epoch 15/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0127 - val_loss: 0.0071 - lr: 0.0010
# Epoch 16/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0130 - val_loss: 0.0072 - lr: 0.0010
# Epoch 17/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0124 - val_loss: 0.0068 - lr: 0.0010
# Epoch 18/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0127 - val_loss: 0.0068 - lr: 0.0010
# Epoch 19/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0124 - val_loss: 0.0082 - lr: 0.0010
# Epoch 20/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0123 - val_loss: 0.0104 - lr: 0.0010
# Epoch 21/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0137 - val_loss: 0.0075 - lr: 0.0010
# Epoch 22/100
# 207/207 [==============================] - 2s 9ms/step - loss: 0.0126 - val_loss: 0.0101 - lr: 0.0010
# Epoch 23/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0116 - val_loss: 0.0088 - lr: 5.0000e-04
# Epoch 24/100
# 207/207 [==============================] - 2s 9ms/step - loss: 0.0117 - val_loss: 0.0064 - lr: 5.0000e-04
# Epoch 25/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0119 - val_loss: 0.0066 - lr: 5.0000e-04
# Epoch 26/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0116 - val_loss: 0.0065 - lr: 5.0000e-04
# Epoch 27/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0116 - val_loss: 0.0068 - lr: 5.0000e-04
# Epoch 28/100
# 207/207 [==============================] - 2s 11ms/step - loss: 0.0122 - val_loss: 0.0064 - lr: 5.0000e-04
# Epoch 29/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0115 - val_loss: 0.0066 - lr: 5.0000e-04
# Epoch 30/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0114 - val_loss: 0.0068 - lr: 5.0000e-04
# Epoch 31/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0116 - val_loss: 0.0067 - lr: 5.0000e-04
# Epoch 32/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0114 - val_loss: 0.0065 - lr: 5.0000e-04
# Epoch 33/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0113 - val_loss: 0.0063 - lr: 2.5000e-04
# Epoch 34/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0111 - val_loss: 0.0065 - lr: 2.5000e-04
# Epoch 35/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0112 - val_loss: 0.0078 - lr: 2.5000e-04
# Epoch 36/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0114 - val_loss: 0.0064 - lr: 2.5000e-04
# Epoch 37/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0114 - val_loss: 0.0082 - lr: 2.5000e-04
# Epoch 38/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0113 - val_loss: 0.0064 - lr: 2.5000e-04
# Epoch 39/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0112 - val_loss: 0.0077 - lr: 2.5000e-04
# Epoch 40/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0112 - val_loss: 0.0062 - lr: 2.5000e-04
# Epoch 41/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0112 - val_loss: 0.0066 - lr: 2.5000e-04
# Epoch 42/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0110 - val_loss: 0.0063 - lr: 2.5000e-04
# Epoch 43/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0112 - val_loss: 0.0066 - lr: 2.5000e-04
# Epoch 44/100
# 207/207 [==============================] - 2s 11ms/step - loss: 0.0111 - val_loss: 0.0063 - lr: 2.5000e-04
# Epoch 45/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0112 - val_loss: 0.0075 - lr: 2.5000e-04
# Epoch 46/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0112 - val_loss: 0.0063 - lr: 2.5000e-04
# Epoch 47/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0110 - val_loss: 0.0071 - lr: 2.5000e-04
# Epoch 48/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0112 - val_loss: 0.0063 - lr: 2.5000e-04
# Epoch 49/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0110 - val_loss: 0.0067 - lr: 1.2500e-04
# Epoch 50/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0110 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 51/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0110 - val_loss: 0.0066 - lr: 1.2500e-04
# Epoch 52/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0110 - val_loss: 0.0064 - lr: 1.2500e-04
# Epoch 53/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0108 - val_loss: 0.0065 - lr: 1.2500e-04
# Epoch 54/100
# 207/207 [==============================] - 2s 9ms/step - loss: 0.0109 - val_loss: 0.0063 - lr: 1.2500e-04
# Epoch 55/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0109 - val_loss: 0.0063 - lr: 1.2500e-04
# Epoch 56/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0109 - val_loss: 0.0063 - lr: 1.2500e-04
# Epoch 57/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0107 - val_loss: 0.0066 - lr: 6.2500e-05

# %%
model_lstm_gru = load_model("alibaba_model_LSTM_GRU_Close.h5")
model_lstm_gru.evaluate(x_test,y_test)
# Out:
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0062
# 0.00623491033911705

# %%
pred_lstm_gru = model_lstm_gru.predict(x_test)
date_for_pred = data['Date'][-len(pred_lstm_gru):]
pred_rescale_lstm_gru = scaler_y.inverse_transform(pred_lstm_gru)

plt.figure(figsize=(15, 6) , facecolor="black")
plt.title("prediction with LSTM & GRU vs true test data" , color="white" , fontsize=20)
plt.plot(date_for_pred,y_test_rescale,color="red" , label='test_actual')
plt.plot(date_for_pred , pred_rescale_lstm_gru,color="blue" ,label='LSTM & GRU model prediction')

ax = plt.gca()
ax.set_facecolor("black")
plt.xlabel("Date" , color="white" , fontsize=15)
plt.ylabel("stock price" , color="white" , fontsize=15)
plt.grid(True , color="gray")
plt.tick_params(colors="white")
plt.legend()
# Out:
# 16/16 [==============================] - 0s 4ms/step

# %% [markdown]
# plot all model

# %%
date_for_pred = data['Date'][-len(pred_lstm_gru):]
plt.figure(figsize=(15, 6) , facecolor="black")
plt.title("prediction of sale of Alibaba" , color="white" , fontsize=20)

plt.plot(date_for_pred,y_test_rescale ,color="green" ,label = 'Actual' , linestyle="-")
plt.plot(date_for_pred,pred_rescale_lstm_gru ,color="red" , label = 'LSTM & GRU' , linestyle="dashed")
plt.plot(date_for_pred,pred_rescale_rnn ,color="blue", label = 'RNN' , linestyle="dashdot")

ax = plt.gca()
ax.set_facecolor("black")
plt.xlabel("Date" , color="white" , fontsize=15)
plt.ylabel("stock price" , color="white" , fontsize=15)
plt.grid(True , color="gray")
plt.tick_params(colors="white")
plt.legend()
plt.show()

# %%
print(f'mean_absolute_error Model RNN(true , prediction) : {mean_absolute_error(y_test_rescale,  pred_rescale_rnn)}')
print(f'mean_squared_error Model RNN(true , prediction) : {mean_squared_error(y_test_rescale,pred_rescale_rnn)}')
print(f'mean_absolute_error Model LSTM & GRU(true , prediction) : {mean_absolute_error(y_test_rescale,  pred_rescale_lstm_gru)}')
print(f'mean_squared_error Model LSTM & GRU(true , prediction) : {mean_squared_error(y_test_rescale,pred_rescale_lstm_gru)}')
# Out:
# mean_absolute_error Model RNN(true , prediction) : 1.5764456996261782
# mean_squared_error Model RNN(true , prediction) : 4.932684662227704
# mean_absolute_error Model LSTM & GRU(true , prediction) : 1.6195181724722059
# mean_squared_error Model LSTM & GRU(true , prediction) : 4.982482043159404

# %%
XTprediction = model_rnn.predict(x_train)
xtprediction = model_rnn.predict(x_test)
pred_rnn = np.concatenate([XTprediction, xtprediction], axis=0)
# Out:
# 65/65 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step

# %%
XTprediction = model_lstm_gru.predict(x_train)
xtprediction = model_lstm_gru.predict(x_test)
pred_lstm = np.concatenate([XTprediction, xtprediction], axis=0)
# Out:
# 65/65 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 3ms/step

# %%
date_for_pred = data['Date'][-len(pred_lstm):]
pred_rescale_rnn = scaler_y.inverse_transform(pred_rnn)
pred_rescale_lstm = scaler_y.inverse_transform(pred_lstm)


plt.figure(figsize=(15, 6) , facecolor="black")
plt.title("prediction of sale of Alibaba" , color="white" , fontsize=20)

plt.plot(date_for_pred , pred_rescale_lstm,color="blue" , label='LSTM & GRU')
plt.plot(date_for_pred , pred_rescale_rnn,color="red" , label='Simple RNN')

ax = plt.gca()
ax.set_facecolor("black")
plt.xlabel("Date" , color="white" , fontsize=15)
plt.ylabel("stock price" , color="white" , fontsize=15)
plt.grid(True , color="gray")
plt.tick_params(colors="white")
plt.legend()
plt.show()
