# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , LSTM , GRU  , SimpleRNN
from tensorflow.keras.callbacks import EarlyStopping , ModelCheckpoint , ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_absolute_error , mean_squared_error
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Ali_Baba_Stock_Data.csv" )
data.head()
# Out:
#          Date  Adj Close      Close       High        Low       Open  \
# 0  2014-09-19  90.673950  93.889999  99.699997  89.949997  92.699997
# 1  2014-09-22  86.810966  89.889999  92.949997  89.500000  92.699997
# 2  2014-09-23  84.184128  87.169998  90.480003  86.620003  88.940002
# 3  2014-09-24  87.467667  90.570000  90.570000  87.220001  88.470001
# 4  2014-09-25  85.874191  88.919998  91.500000  88.500000  91.089996
#
#       Volume
# 0  271879400
# 1   66657800
# 2   39009800
# 3   32088000
# 4   28598000

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2617 entries, 0 to 2616
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2617 non-null   datetime64[ns]
#  1   Adj Close  2617 non-null   float64
#  2   Close      2617 non-null   float64
#  3   High       2617 non-null   float64
#  4   Low        2617 non-null   float64
#  5   Open       2617 non-null   float64
#  6   Volume     2617 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 143.2 KB

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.head()
# Out:
#         Date  Adj Close      Close       High        Low       Open     Volume
# 0 2014-09-19  90.673950  93.889999  99.699997  89.949997  92.699997  271879400
# 1 2014-09-22  86.810966  89.889999  92.949997  89.500000  92.699997   66657800
# 2 2014-09-23  84.184128  87.169998  90.480003  86.620003  88.940002   39009800
# 3 2014-09-24  87.467667  90.570000  90.570000  87.220001  88.470001   32088000
# 4 2014-09-25  85.874191  88.919998  91.500000  88.500000  91.089996   28598000

# %%
data.isnull().sum()
# Out:
# Date         0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                                 Date    Adj Close        Close         High  \
# count                           2617  2617.000000  2617.000000  2617.000000
# mean   2019-11-30 14:35:26.709973248   130.763001   135.153905   136.919684
# min              2014-09-19 00:00:00    55.424198    57.389999    58.650002
# 25%              2017-04-26 00:00:00    82.445793    84.849998    85.699997
# 50%              2019-11-29 00:00:00   105.469185   108.989998   110.650002
# 75%              2022-07-07 00:00:00   173.061798   179.199997   181.389999
# max              2025-02-13 00:00:00   306.276886   317.140015   319.320007
# std                              NaN    56.741744    58.951556    59.579593
#
#                Low         Open        Volume
# count  2617.000000  2617.000000  2.617000e+03
# mean    133.360942   135.248746  1.899231e+07
# min      57.200001    57.299999  3.775300e+06
# 25%      84.000000    85.000000  1.186070e+07
# 50%     107.260002   108.500000  1.600840e+07
# 75%     177.000000   179.369995  2.172430e+07
# max     308.910004   313.500000  2.718794e+08
# std      58.244218    59.037467  1.291504e+07

# %%
plt.plot(data['Date'], data['High'] , label = 'High Price' , c="green")
plt.legend()
plt.show()

# %%
X = data[["Close","Low","Open","Volume"]].values
Y = data['High'].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# %%
x_scale = scaler_x.fit_transform(X)
y_scale = scaler_y.fit_transform(Y.reshape(-1, 1))

# %%
x_train , x_test , y_train , y_test = train_test_split(x_scale , y_scale , test_size = 0.2 , shuffle=False)
print(f"len x_train : {len(x_train)} , len y_train : {len(y_train)}")
print(f"len x_test: {len(x_test)} , len y_test : {len(y_test)}")
# Out:
# len x_train : 2093 , len y_train : 2093
# len x_test: 524 , len y_test : 524

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
def create_dataset(X , Y, time_step=30):
    dataX = []
    dataY = []
    for i in range(len(X)-time_step):
        d = i + time_step
        dataX.append(X[i:d])
        dataY.append(Y[d])
    return np.array(dataX), np.array(dataY)

# %%
time_steps = 30
x_train , y_train = create_dataset(x_train, y_train, time_steps)
x_test , y_test = create_dataset(x_test, y_test, time_steps)

# %%
print(f"type of XT  is {type(x_train)}")
print(f"type of YT  is {type(y_train)}")
print(f"type of XT  is {type(x_test)}")
print(f"type of YT  is {type(y_test)}")
# Out:
# type of XT  is <class 'numpy.ndarray'>
# type of YT  is <class 'numpy.ndarray'>
# type of XT  is <class 'numpy.ndarray'>
# type of YT  is <class 'numpy.ndarray'>

# %%
x_train.shape
# Out:
# (2063, 30, 4)

# %%
y_train.shape
# Out:
# (2063, 1)

# %%
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2])

# %%
print(f"shape of XT is {x_train.shape}")
print(f"shape of YT is {y_train.shape}")
print(f"shape of xt is {x_test.shape}")
print(f"shape of yt is {y_test.shape}")
# Out:
# shape of XT is (2063, 30, 4)
# shape of YT is (2063, 1)
# shape of xt is (494, 30, 4)
# shape of yt is (494, 1)

# %% [markdown]
# RNN

# %%
model_rnn = Sequential()
model_rnn.add(SimpleRNN(50,activation="relu" , return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])))
model_rnn.add(SimpleRNN(50,activation="relu"))
model_rnn.add(Dense(1))

# %%
early_stopping2 = EarlyStopping(monitor="val_loss" , mode="min" , patience=30)
rrop2 = ReduceLROnPlateau(monitor="val_loss" , mode="min" , factor=0.5 , learning_rate=1e-6 , patience=20)
check_point2 = ModelCheckpoint("alibaba_model_RNN_HIGH.h5", monitor="val_loss" , save_best_only=True)

# %%
model_rnn.compile(optimizer="adam", loss='mean_absolute_error')
model_rnn.fit(x_train, y_train,validation_data=(x_test,y_test) ,  epochs=100, batch_size=32 , callbacks=[early_stopping2 , rrop2 , check_point2])
# Out:
# Epoch 1/100
# 65/65 [==============================] - 2s 10ms/step - loss: 0.0426 - val_loss: 0.0082 - lr: 0.0010
# Epoch 2/100
# 33/65 [==============>...............] - ETA: 0s - loss: 0.0141
# c:\Users\T A T\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 65/65 [==============================] - 0s 7ms/step - loss: 0.0135 - val_loss: 0.0076 - lr: 0.0010
# Epoch 3/100
# 65/65 [==============================] - 0s 7ms/step - loss: 0.0136 - val_loss: 0.0076 - lr: 0.0010
# Epoch 4/100
# 65/65 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0071 - lr: 0.0010
# Epoch 5/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 0.0073 - lr: 0.0010
# Epoch 6/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0067 - lr: 0.0010
# Epoch 7/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0110 - val_loss: 0.0075 - lr: 0.0010
# Epoch 8/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0112 - val_loss: 0.0076 - lr: 0.0010
# Epoch 9/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0063 - lr: 0.0010
# Epoch 10/100
# 65/65 [==============================] - 0s 7ms/step - loss: 0.0107 - val_loss: 0.0061 - lr: 0.0010
# Epoch 11/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0062 - lr: 0.0010
# Epoch 12/100
# 65/65 [==============================] - 0s 7ms/step - loss: 0.0108 - val_loss: 0.0060 - lr: 0.0010
# Epoch 13/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0067 - lr: 0.0010
# Epoch 14/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0060 - lr: 0.0010
# Epoch 15/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0103 - val_loss: 0.0061 - lr: 0.0010
# Epoch 16/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0092 - val_loss: 0.0061 - lr: 0.0010
# Epoch 17/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0096 - val_loss: 0.0058 - lr: 0.0010
# Epoch 18/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0065 - lr: 0.0010
# Epoch 19/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0061 - lr: 0.0010
# Epoch 20/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0068 - lr: 0.0010
# Epoch 21/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0091 - val_loss: 0.0058 - lr: 0.0010
# Epoch 22/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0092 - val_loss: 0.0065 - lr: 0.0010
# Epoch 23/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0093 - val_loss: 0.0064 - lr: 0.0010
# Epoch 24/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0063 - lr: 0.0010
# Epoch 25/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0094 - val_loss: 0.0075 - lr: 0.0010
# Epoch 26/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0059 - lr: 0.0010
# Epoch 27/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0088 - val_loss: 0.0060 - lr: 0.0010
# Epoch 28/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0089 - val_loss: 0.0061 - lr: 0.0010
# Epoch 29/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0092 - val_loss: 0.0058 - lr: 0.0010
# Epoch 30/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0094 - val_loss: 0.0062 - lr: 0.0010
# Epoch 31/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0059 - lr: 0.0010
# Epoch 32/100
# 65/65 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0057 - lr: 0.0010
# Epoch 33/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0096 - val_loss: 0.0057 - lr: 0.0010
# Epoch 34/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0089 - val_loss: 0.0064 - lr: 0.0010
# Epoch 35/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0091 - val_loss: 0.0065 - lr: 0.0010
# Epoch 36/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0060 - lr: 0.0010
# Epoch 37/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0087 - val_loss: 0.0057 - lr: 0.0010
# Epoch 38/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0072 - lr: 0.0010
# Epoch 39/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0058 - lr: 0.0010
# Epoch 40/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0091 - val_loss: 0.0058 - lr: 0.0010
# Epoch 41/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0088 - val_loss: 0.0060 - lr: 0.0010
# Epoch 42/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0058 - lr: 0.0010
# Epoch 43/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0094 - val_loss: 0.0057 - lr: 0.0010
# Epoch 44/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0094 - val_loss: 0.0062 - lr: 0.0010
# Epoch 45/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0059 - lr: 0.0010
# Epoch 46/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0071 - lr: 0.0010
# Epoch 47/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0060 - lr: 0.0010
# Epoch 48/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0073 - lr: 0.0010
# Epoch 49/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0093 - val_loss: 0.0058 - lr: 0.0010
# Epoch 50/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0058 - lr: 0.0010
# Epoch 51/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0089 - val_loss: 0.0060 - lr: 0.0010
# Epoch 52/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0089 - val_loss: 0.0058 - lr: 0.0010
# Epoch 53/100
# 65/65 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0057 - lr: 5.0000e-04
# Epoch 54/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0085 - val_loss: 0.0059 - lr: 5.0000e-04
# Epoch 55/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0057 - lr: 5.0000e-04
# Epoch 56/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0085 - val_loss: 0.0066 - lr: 5.0000e-04
# Epoch 57/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0083 - val_loss: 0.0057 - lr: 5.0000e-04
# Epoch 58/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0064 - lr: 5.0000e-04
# Epoch 59/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0063 - lr: 5.0000e-04
# Epoch 60/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0060 - lr: 5.0000e-04
# Epoch 61/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0087 - val_loss: 0.0061 - lr: 5.0000e-04
# Epoch 62/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0085 - val_loss: 0.0057 - lr: 5.0000e-04
# Epoch 63/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0066 - lr: 5.0000e-04
# Epoch 64/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0059 - lr: 5.0000e-04
# Epoch 65/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0058 - lr: 5.0000e-04
# Epoch 66/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0061 - lr: 5.0000e-04
# Epoch 67/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0058 - lr: 5.0000e-04
# Epoch 68/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0061 - lr: 5.0000e-04
# Epoch 69/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0059 - lr: 5.0000e-04
# Epoch 70/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0059 - lr: 5.0000e-04
# Epoch 71/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0065 - lr: 5.0000e-04
# Epoch 72/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0084 - val_loss: 0.0060 - lr: 5.0000e-04
# Epoch 73/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0058 - lr: 2.5000e-04
# Epoch 74/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0081 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 75/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0082 - val_loss: 0.0058 - lr: 2.5000e-04
# Epoch 76/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0059 - lr: 2.5000e-04
# Epoch 77/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0062 - lr: 2.5000e-04
# Epoch 78/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0082 - val_loss: 0.0065 - lr: 2.5000e-04
# Epoch 79/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0060 - lr: 2.5000e-04
# Epoch 80/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 81/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0082 - val_loss: 0.0057 - lr: 2.5000e-04
# Epoch 82/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0081 - val_loss: 0.0060 - lr: 2.5000e-04
# Epoch 83/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0081 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 84/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0063 - lr: 2.5000e-04
# Epoch 85/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0057 - lr: 2.5000e-04
# Epoch 86/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0057 - lr: 2.5000e-04
# Epoch 87/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0058 - lr: 2.5000e-04
# Epoch 88/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0057 - lr: 2.5000e-04
# Epoch 89/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0081 - val_loss: 0.0057 - lr: 2.5000e-04
# Epoch 90/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0083 - val_loss: 0.0057 - lr: 2.5000e-04
# Epoch 91/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0083 - val_loss: 0.0060 - lr: 2.5000e-04
# Epoch 92/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0080 - val_loss: 0.0061 - lr: 2.5000e-04
# Epoch 93/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0060 - lr: 1.2500e-04
# Epoch 94/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0058 - lr: 1.2500e-04
# Epoch 95/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0060 - lr: 1.2500e-04
# Epoch 96/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 97/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0079 - val_loss: 0.0058 - lr: 1.2500e-04
# Epoch 98/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0057 - lr: 1.2500e-04
# Epoch 99/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0081 - val_loss: 0.0057 - lr: 1.2500e-04
# Epoch 100/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0079 - val_loss: 0.0057 - lr: 1.2500e-04

# %%
model_rnn = load_model("alibaba_model_RNN_HIGH.h5")
model_rnn.evaluate(x_test,y_test)
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0057
# 0.005686136428266764

# %%
y_pred_rnn = model_rnn.predict(x_test)
date_for_pred = data['Date'][-len(y_pred_rnn):]
pred_rescale_rnn = scaler_y.inverse_transform(y_pred_rnn)
y_test_rescale = scaler_y.inverse_transform(y_test)
plt.figure(figsize=(15, 5))
plt.plot(date_for_pred , y_test_rescale,color = "red" , label='true test data')
plt.plot(date_for_pred , pred_rescale_rnn,color="green" , label='prediction')
plt.legend()
plt.show()
# Out:
# 16/16 [==============================] - 0s 3ms/step

# %% [markdown]
# GRU , LSTM

# %%
model_lstm_gru = Sequential()
model_lstm_gru.add(GRU(units = 50, return_sequences = True, activation = 'relu' , input_shape=(x_train.shape[1],x_train.shape[2])))
model_lstm_gru.add(LSTM(units = 50, activation = 'relu'))
model_lstm_gru.add(Dense(1))

# %%
early_stopping = EarlyStopping(monitor="val_loss" , mode="min" , patience=17)
rrop = ReduceLROnPlateau(monitor="val_loss" , mode="min" , factor=0.5 , learning_rate=1e-6 , patience=8)
check_point = ModelCheckpoint("alibaba_model_LSTM_GRU_HIGH.h5", monitor="val_loss" , save_best_only=True)

# %%
model_lstm_gru.compile(loss='mean_absolute_error', optimizer='adam')
history = model_lstm_gru.fit(x_train , y_train , validation_data=(x_test , y_test) , epochs = 100 , batch_size=10 , callbacks=[early_stopping , rrop , check_point])
# Out:
# Epoch 1/100
# 207/207 [==============================] - 4s 12ms/step - loss: 0.0421 - val_loss: 0.0130 - lr: 0.0010
# Epoch 2/100
#  13/207 [>.............................] - ETA: 1s - loss: 0.0187
# c:\Users\T A T\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0188 - val_loss: 0.0112 - lr: 0.0010
# Epoch 3/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0160 - val_loss: 0.0099 - lr: 0.0010
# Epoch 4/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0141 - val_loss: 0.0135 - lr: 0.0010
# Epoch 5/100
# 207/207 [==============================] - 2s 11ms/step - loss: 0.0128 - val_loss: 0.0080 - lr: 0.0010
# Epoch 6/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0124 - val_loss: 0.0082 - lr: 0.0010
# Epoch 7/100
# 207/207 [==============================] - 2s 11ms/step - loss: 0.0125 - val_loss: 0.0069 - lr: 0.0010
# Epoch 8/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0118 - val_loss: 0.0067 - lr: 0.0010
# Epoch 9/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0112 - val_loss: 0.0092 - lr: 0.0010
# Epoch 10/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0116 - val_loss: 0.0064 - lr: 0.0010
# Epoch 11/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0105 - val_loss: 0.0072 - lr: 0.0010
# Epoch 12/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0104 - val_loss: 0.0060 - lr: 0.0010
# Epoch 13/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0109 - val_loss: 0.0066 - lr: 0.0010
# Epoch 14/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0099 - val_loss: 0.0060 - lr: 0.0010
# Epoch 15/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0102 - val_loss: 0.0063 - lr: 0.0010
# Epoch 16/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0105 - val_loss: 0.0073 - lr: 0.0010
# Epoch 17/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0099 - val_loss: 0.0061 - lr: 0.0010
# Epoch 18/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0100 - val_loss: 0.0059 - lr: 0.0010
# Epoch 19/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0099 - val_loss: 0.0063 - lr: 0.0010
# Epoch 20/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0098 - val_loss: 0.0068 - lr: 0.0010
# Epoch 21/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0092 - val_loss: 0.0066 - lr: 5.0000e-04
# Epoch 22/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0091 - val_loss: 0.0057 - lr: 5.0000e-04
# Epoch 23/100
# 207/207 [==============================] - 2s 9ms/step - loss: 0.0090 - val_loss: 0.0072 - lr: 5.0000e-04
# Epoch 24/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0091 - val_loss: 0.0057 - lr: 5.0000e-04
# Epoch 25/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0095 - val_loss: 0.0057 - lr: 5.0000e-04
# Epoch 26/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0091 - val_loss: 0.0076 - lr: 5.0000e-04
# Epoch 27/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0095 - val_loss: 0.0070 - lr: 5.0000e-04
# Epoch 28/100
# 207/207 [==============================] - 2s 9ms/step - loss: 0.0092 - val_loss: 0.0066 - lr: 5.0000e-04
# Epoch 29/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0094 - val_loss: 0.0083 - lr: 5.0000e-04
# Epoch 30/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0091 - val_loss: 0.0074 - lr: 5.0000e-04
# Epoch 31/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0088 - val_loss: 0.0064 - lr: 2.5000e-04
# Epoch 32/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0086 - val_loss: 0.0057 - lr: 2.5000e-04
# Epoch 33/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0088 - val_loss: 0.0058 - lr: 2.5000e-04
# Epoch 34/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0090 - val_loss: 0.0056 - lr: 2.5000e-04
# Epoch 35/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0089 - val_loss: 0.0057 - lr: 2.5000e-04
# Epoch 36/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0087 - val_loss: 0.0071 - lr: 2.5000e-04
# Epoch 37/100
# 207/207 [==============================] - 2s 9ms/step - loss: 0.0090 - val_loss: 0.0056 - lr: 2.5000e-04
# Epoch 38/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0087 - val_loss: 0.0076 - lr: 2.5000e-04
# Epoch 39/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0086 - val_loss: 0.0056 - lr: 1.2500e-04
# Epoch 40/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0085 - val_loss: 0.0056 - lr: 1.2500e-04
# Epoch 41/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0085 - val_loss: 0.0059 - lr: 1.2500e-04
# Epoch 42/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0085 - val_loss: 0.0062 - lr: 1.2500e-04
# Epoch 43/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0085 - val_loss: 0.0056 - lr: 1.2500e-04
# Epoch 44/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0085 - val_loss: 0.0059 - lr: 1.2500e-04
# Epoch 45/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0084 - val_loss: 0.0057 - lr: 1.2500e-04
# Epoch 46/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0084 - val_loss: 0.0057 - lr: 1.2500e-04
# Epoch 47/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0084 - val_loss: 0.0056 - lr: 6.2500e-05
# Epoch 48/100
# 207/207 [==============================] - 2s 9ms/step - loss: 0.0084 - val_loss: 0.0057 - lr: 6.2500e-05
# Epoch 49/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 0.0056 - lr: 6.2500e-05
# Epoch 50/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 0.0057 - lr: 6.2500e-05
# Epoch 51/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 0.0056 - lr: 6.2500e-05
# Epoch 52/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 0.0057 - lr: 6.2500e-05
# Epoch 53/100
# 207/207 [==============================] - 2s 9ms/step - loss: 0.0083 - val_loss: 0.0056 - lr: 6.2500e-05
# Epoch 54/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 0.0060 - lr: 6.2500e-05
# Epoch 55/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 0.0058 - lr: 3.1250e-05
# Epoch 56/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 0.0058 - lr: 3.1250e-05
# Epoch 57/100
# 207/207 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 0.0057 - lr: 3.1250e-05

# %%
model_lstm_gru = load_model("alibaba_model_LSTM_GRU_HIGH.h5")
model_lstm_gru.evaluate(x_test,y_test)
# Out:
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0056
# 0.005600522272288799

# %%
pred_lstm_gru = model_lstm_gru.predict(x_test)
date_for_pred = data['Date'][-len(pred_lstm_gru):]
pred_rescale_lstm_gru = scaler_y.inverse_transform(pred_lstm_gru)
plt.figure(figsize=(15, 5))
plt.plot(date_for_pred,y_test_rescale,color="red" , label='test_actual')
plt.plot(date_for_pred , pred_rescale_lstm_gru,color="green" ,label='LSTM & GRU model prediction')
plt.legend()
plt.show()
# Out:
# 16/16 [==============================] - 0s 4ms/step

# %% [markdown]
# plot all model

# %%
date_for_pred = data['Date'][-len(pred_lstm_gru):]
plt.figure(figsize=(20,10))
plt.plot(date_for_pred,y_test_rescale ,color="green" ,label = 'Actual' , linestyle="-")
plt.plot(date_for_pred,pred_rescale_lstm_gru ,color="red" , label = 'LSTM & GRU' , linestyle="dashed")
plt.plot(date_for_pred,pred_rescale_rnn ,color="blue", label = 'RNN' , linestyle="dashdot")
plt.title('Alibaba Stock Prediction')
plt.ylabel('Stock Price')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
print(f'mean_absolute_error(true , prediction) : {mean_absolute_error(y_test_rescale,  pred_rescale_rnn)}')
print(f'mean_squared_error(true , prediction) : {mean_squared_error(y_test_rescale,pred_rescale_rnn)}')
# Out:
# mean_absolute_error(true , prediction) : 1.4822052097101543
# mean_squared_error(true , prediction) : 4.356744696321107

# %%
XTprediction = model_rnn.predict(x_train)
xtprediction = model_rnn.predict(x_test)
pred_rnn = np.concatenate([XTprediction, xtprediction], axis=0)
# Out:
# 65/65 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step

# %%
XTprediction = model_lstm_gru.predict(x_train)
xtprediction = model_lstm_gru.predict(x_test)
pred_lstm = np.concatenate([XTprediction, xtprediction], axis=0)
# Out:
# 65/65 [==============================] - 0s 4ms/step
# 16/16 [==============================] - 0s 4ms/step

# %%
date_for_pred = data['Date'][-len(pred_lstm):]
pred_rescale_rnn = scaler_y.inverse_transform(pred_rnn)
pred_rescale_lstm = scaler_y.inverse_transform(pred_lstm)
plt.figure(figsize=(15, 5))
plt.plot(date_for_pred , pred_rescale_lstm,color="blue" , label='LSTM & GRU')
plt.plot(date_for_pred , pred_rescale_rnn,color="red" , label='Simple RNN')
plt.legend()
plt.show()

# %%
date_for_actual = data['Date'][-len(X):]
plt.figure(figsize=(15, 5))
plt.plot(date_for_actual , Y,color = "green" , label='Actual')
